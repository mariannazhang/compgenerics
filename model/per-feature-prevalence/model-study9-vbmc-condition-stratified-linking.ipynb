# %% [markdown]
# # Study 9: condition-stratified GP inference WITH linking function
#
# Same model as `model-study9-vbmc.ipynb` (Beta-mixture linking function, once-per-eval fit of the
# shapes, NUTS over coherences, pyVBMC over `(length_scale, mu_0)`) — but **stratified by condition**.
#
# Each condition heard generics only about its own region (diet / personality / physical training
# features; heterogeneous = `in_heterogenous`), so each condition gets its own coherence field. The GP
# hyperparameters `(length_scale, mu_0)`, output_scale, beta, **and the per-feature Beta shapes** are
# shared across conditions. Crucially, the shapes are **condition-invariant** (a feature's response
# style is the same in every condition), while coherence is **condition-specific** — so:
#
# - the per-feature Beta shapes absorb each feature's *baseline* prevalence (real-world priors that are
#   constant across conditions), and
# - coherence / `length_scale` is identified by the *cross-condition contrast* (a feature rated higher
#   when its region was trained), which the shapes cannot absorb.
#
# This is the full dual model — per-feature priors *and* a generalization effect — now identifiable
# because stratification separates them.

# %%
import os
os.environ["JAX_PLATFORMS"] = "cpu"

import sys, csv, pickle as pkl
sys.path.insert(0, ".")

import numpy as np
import jax
import jax.numpy as jnp
import blackjax
import matplotlib.pyplot as plt
from scipy.special import logsumexp as scipy_logsumexp
from pyvbmc import VBMC

from model_jax import (
    make_log_density_fn_joint,
    fit_beta_mixtures_all_features,
    beta_mixture_log_likelihood,
)
print(f"backend: {jax.default_backend()}")
# Out:
# backend: cpu

# %%
# ---- features: per-condition trained set + shared test set ----
with open('../features/set2_features_dataframe.pkl', 'rb') as f:
    df = pkl.load(f)
feat_idx = df.set_index('feature')
train_df = df[df.split == 'train']

CONDITIONS  = ['diet', 'personality', 'physical', 'heterogeneous']
CAT_OF_COND = {'diet':'diet_preferences', 'personality':'personality_behaviors', 'physical':'physical'}
CAT_SHORT   = {'diet_preferences':'diet', 'personality_behaviors':'personality', 'physical':'physical'}

x_train_cond, u_train_cond = {}, {}
for c in CONDITIONS:
    sub = train_df[train_df.in_heterogenous] if c == 'heterogeneous' else train_df[train_df.category == CAT_OF_COND[c]]
    x_train_cond[c] = jnp.array(sub[['x_2d', 'y_2d']].values)
    u_train_cond[c] = jnp.zeros(len(sub), dtype=jnp.int32)   # all generic, localized to the region
    print(f"  {c:<14}: {len(sub)} trained features")

CSV_TO_FEATURE = {
    'diet_can_eat_spicy_1':'can eat spicy food','diet_breakfast_late_1':'eat breakfast very late',
    'diet_five_meals_day_1':'eat five meals a day','diet_like_juice_pulp_1':'like juice with pulp',
    'diet_pepper_on_all_1':'put pepper on all their foods','pers_cry_easily_1':'cry easily',
    'pers_collect_rocks_1':'like to collect rocks','pers_like_to_dance_1':'like to dance',
    'pers_like_highfive_1':'like to give high-fives','pers_read_books_1':'like to read books',
    'phys_can_roll_tongue_1':'can roll their tongue','phys_can_snap_toes_1':'can snap with their toes',
    'phys_can_wiggle_ears_1':'can wiggle their ears','phys_cold_hands_feet_1':'have cold hands and feet',
    'phys_snore_sleep_1':'snore when they sleep'}
TEST_CSV_COLS      = list(CSV_TO_FEATURE.keys())
test_feature_names = list(CSV_TO_FEATURE.values())
x_test     = jnp.array([feat_idx.loc[n, ['x_2d','y_2d']].values for n in test_feature_names])  # (J,2)
test_trait = [CAT_SHORT[feat_idx.loc[n, 'category']] for n in test_feature_names]
J = x_test.shape[0]
print(f"test features: {J}")
# Out:
#   diet          : 15 trained features
#   personality   : 15 trained features
#   physical      : 15 trained features
#   heterogeneous : 15 trained features
# test features: 15

# %%
# ---- ratings, stratified by condition (+ a stacked copy for the shared shape fit) ----
with open('../../data/study9.csv') as f:
    rows = list(csv.reader(f))
hdr = rows[0]; col_idx = [hdr.index(c) for c in TEST_CSV_COLS]; cond_i = hdr.index('condition')

R, cond = [], []
for r in rows[3:]:
    try:
        R.append([int(r[i]) / 100.0 for i in col_idx])
    except (ValueError, IndexError):
        continue
    cond.append(r[cond_i])
R = np.array(R); cond = np.array(cond)

responses_cond = {c: jnp.array(R[cond == c]) for c in CONDITIONS}
# stacked in condition order — used to fit the shared Beta shapes across all participants
responses_all  = jnp.concatenate([responses_cond[c] for c in CONDITIONS], axis=0)
N_cond = {c: int(responses_cond[c].shape[0]) for c in CONDITIONS}
for c in CONDITIONS:
    print(f"  {c:<14}: {N_cond[c]} participants")
print(f"stacked responses_all: {responses_all.shape}")
# Out:
#   diet          : 101 participants
#   personality   : 101 participants
#   physical      : 101 participants
#   heterogeneous : 99 participants
# stacked responses_all: (402, 15)

# %%
FIXED_PARAMS = {'output_scale': 1.5, 'beta': 3.0}
N_WARMUP  = 300
N_SAMPLES = 800        # per condition; 4 chains per eval
STEP      = 5
MAX_EVALS = 120        # VBMC budget (main cost knob; 4 MCMC chains/eval)

def condition_pz1_draws(x_train_c, u_train_c, params):
    """Thinned coherence draws (S, J) = sigmoid(y_test) for one condition's trained region."""
    ldf = make_log_density_fn_joint(u_train_c, x_train_c, x_test, params)
    ip  = {'training_coherences': jnp.zeros(x_train_c.shape[0]), 'test_coherences': jnp.zeros(J)}
    k = jax.random.PRNGKey(0); k, wk = jax.random.split(k)
    w = blackjax.window_adaptation(blackjax.nuts, ldf)
    (st, npar), _ = w.run(wk, ip, num_steps=N_WARMUP)
    nuts = blackjax.nuts(ldf, **npar); step = jax.jit(lambda s, key: nuts.step(key, s))
    tc = []
    for key in jax.random.split(k, N_SAMPLES)[:-1]:
        st, _ = step(st, key)
        tc.append(np.array(st.position['test_coherences']))
    return np.array(jax.nn.sigmoid(np.array(tc)[::STEP]))   # (S, J)

# %%
eval_count = [0]
eval_log   = []

def log_joint(phi):
    """Condition-stratified log joint with a SHARED Beta-mixture linking function.

    Per eval: sample each condition's coherences; fit the per-feature shapes ONCE across all
    participants using condition-specific weights (shapes shared, condition-invariant); then score
    each condition's draws against those shared shapes and sum. phi = [log_ls, mu_0].
    """
    log_ls, mu_0 = float(phi[0]), float(phi[1])
    length_scale = float(np.exp(log_ls))
    eval_count[0] += 1
    print(f"  eval {eval_count[0]:3d}: ls={length_scale:.3f}  mu_0={mu_0:.3f}", end="  ")

    log_prior = float(-0.5*((log_ls-np.log(0.5))/1.5)**2) + float(-0.5*mu_0**2)
    params = {**FIXED_PARAMS, 'length_scale': length_scale, 'mu_0': mu_0}

    # 1. per-condition coherence draws
    pz1_draws = {c: condition_pz1_draws(x_train_cond[c], u_train_cond[c], params) for c in CONDITIONS}
    pz1_bar   = {c: pz1_draws[c].mean(axis=0) for c in CONDITIONS}

    # 2. SHARED shapes: fit once across all participants, each weighted by THEIR condition's pz1
    pz1_weights = jnp.concatenate(
        [jnp.tile(jnp.array(pz1_bar[c]), (N_cond[c], 1)) for c in CONDITIONS], axis=0)  # (N_total, J)
    beta_params = fit_beta_mixtures_all_features(responses_all, pz1_weights)            # (J, 4) shared

    # 3. score each condition's draws under the shared shapes; logsumexp over draws; sum
    total_ll, var_terms = 0.0, []
    for c in CONDITIONS:
        S = pz1_draws[c].shape[0]
        ll_s = [float(beta_mixture_log_likelihood(responses_cond[c], jnp.array(pz1_draws[c][s]), beta_params))
                for s in range(S)]
        total_ll += float(scipy_logsumexp(ll_s) - np.log(S))
        var_terms.append(np.var(ll_s))

    noise_std = float(np.sqrt(sum(var_terms)))   # combined MC noise across conditions
    log_joint_val = float(total_ll + log_prior)
    print(f"log_lik={total_ll:.1f}  noise_std={noise_std:.2f}  log_joint={log_joint_val:.1f}")
    eval_log.append((np.array(phi, dtype=float), log_joint_val, noise_std))
    return log_joint_val, max(noise_std, 1.0)

# %%
# pyVBMC varG-squeeze patch (numpy-compat fix; same as the other notebooks)
import pyvbmc.vbmc.variational_optimization as _vopt
if not getattr(_vopt._gp_log_joint, "_varg_squeeze_patch", False):
    _orig = _vopt._gp_log_joint
    def _patched(*a, **k):
        out = list(_orig(*a, **k)); out[2] = None if out[2] is None else float(np.squeeze(out[2])); return tuple(out)
    _patched._varg_squeeze_patch = True; _vopt._gp_log_joint = _patched
    print("patched _gp_log_joint (varG squeeze)")

x0  = np.array([np.log(0.3), 0.0])
lb  = np.array([np.log(0.03), -4.0])
ub  = np.array([np.log(2.5),   4.0])     # ~3x cloud diameter (0.78); above this = trait-blind
plb = np.array([np.log(0.08), -2.0])
pub = np.array([np.log(1.0),   2.0])
print(f"Start ls={np.exp(x0[0]):.2f}, mu_0={x0[1]:.2f}  | bounds ls in [{np.exp(lb[0]):.2f},{np.exp(ub[0]):.2f}]")

vbmc = VBMC(log_joint, x0, lb, ub, plb, pub,
            options={'specify_target_noise': True, 'max_fun_evals': MAX_EVALS})
vbmc_result, vbmc_stats = vbmc.optimize()
# Out:
# patched _gp_log_joint (varG squeeze)
# Start ls=0.30, mu_0=0.00  | bounds ls in [0.03,2.50]
# Reshaping x0 to row vector.
# Reshaping lower bounds to (1, 2).
# Reshaping upper bounds to (1, 2).
# Reshaping plausible lower bounds to (1, 2).
# Reshaping plausible upper bounds to (1, 2).
# Beginning variational optimization assuming NOISY observations of the log-joint
#  Iteration  f-count    Mean[ELBO]    Std[ELBO]    sKL-iter[q]   K[q]  Convergence  Action
#   eval   1: ls=0.300  mu_0=0.000  log_lik=-26718.1  noise_std=88.24  log_joint=-26718.2
#   eval   2: ls=0.505  mu_0=-0.620  log_lik=-26709.3  noise_std=105.04  log_joint=-26709.5
#   eval   3: ls=0.597  mu_0=-0.065  log_lik=-26765.9  noise_std=96.17  log_joint=-26765.9
#   eval   4: ls=0.489  mu_0=-1.149  log_lik=-26659.0  noise_std=91.24  log_joint=-26659.6
#   eval   5: ls=0.529  mu_0=1.710  log_lik=-26811.0  noise_std=95.03  log_joint=-26812.5
#   eval   6: ls=0.192  mu_0=0.333  log_lik=-26737.7  noise_std=83.10  log_joint=-26738.0
#   eval   7: ls=0.732  mu_0=1.627  log_lik=-26848.2  noise_std=80.14  log_joint=-26849.5
#   eval   8: ls=0.966  mu_0=1.165  log_lik=-26823.2  noise_std=135.01  log_joint=-26823.9
#   eval   9: ls=0.432  mu_0=0.333  log_lik=-26777.6  noise_std=94.88  log_joint=-26777.7
#   eval  10: ls=0.546  mu_0=1.759  log_lik=-26852.5  noise_std=116.59  log_joint=-26854.1
#      0         10      -26729.48        23.14   5669836.86        2        inf     start warm-up
#   eval  11: ls=0.311  mu_0=-1.012  log_lik=-26605.3  noise_std=97.92  log_joint=-26605.8
#   eval  12: ls=0.194  mu_0=-0.482  log_lik=-26628.7  noise_std=91.71  log_joint=-26629.0
#   eval  13: ls=0.226  mu_0=0.678  log_lik=-26779.1  noise_std=87.30  log_joint=-26779.5
#   eval  14: ls=0.054  mu_0=-3.025  log_lik=-26616.2  noise_std=257.90  log_joint=-26621.9
#   eval  15: ls=0.126  mu_0=-1.725  log_lik=-26523.0  noise_std=116.37  log_joint=-26524.9
#      1         15      -26619.92        56.03        20.94        2        inf
#   eval  16: ls=0.156  mu_0=-1.918  log_lik=-26511.3  noise_std=115.43  log_joint=-26513.4
#   eval  17: ls=0.251  mu_0=-1.760  log_lik=-26555.1  noise_std=111.08  log_joint=-26556.8
#   eval  18: ls=0.161  mu_0=1.187  log_lik=-26703.8  noise_std=113.26  log_joint=-26704.8
#   eval  19: ls=0.714  mu_0=-2.996  log_lik=-26601.7  noise_std=90.33  log_joint=-26606.3
#   eval  20: ls=0.382  mu_0=-2.042  log_lik=-26575.9  noise_std=103.03  log_joint=-26578.0
#      2         20      -26581.82        39.02        21.37        2        529
#   eval  21: ls=0.081  mu_0=-0.086  log_lik=-26667.4  noise_std=78.13  log_joint=-26668.1
#   eval  22: ls=0.270  mu_0=-3.044  log_lik=-26521.4  noise_std=128.18  log_joint=-26526.1
#   eval  23: ls=0.086  mu_0=-3.064  log_lik=-26593.7  noise_std=243.55  log_joint=-26599.1
#   eval  24: ls=0.065  mu_0=-2.485  log_lik=-26470.4  noise_std=121.05  log_joint=-26474.4
#   eval  25: ls=0.036  mu_0=-2.768  log_lik=-27071.1  noise_std=364.64  log_joint=-27076.5
#      3         25      -26571.61        48.96         3.08        2       92.4
#   eval  26: ls=0.181  mu_0=0.207  log_lik=-26710.4  noise_std=83.16  log_joint=-26710.7
#   eval  27: ls=0.485  mu_0=-2.604  log_lik=-26585.1  noise_std=86.44  log_joint=-26588.5
#   eval  28: ls=0.342  mu_0=-2.946  log_lik=-26549.5  noise_std=111.05  log_joint=-26553.8
#   eval  29: ls=0.304  mu_0=-2.565  log_lik=-26558.1  noise_std=115.96  log_joint=-26561.4
#   eval  30: ls=0.318  mu_0=-2.635  log_lik=-26535.7  noise_std=111.42  log_joint=-26539.3
#      4         30      -26590.58        32.00         3.29        2       94.5
#   eval  31: ls=0.081  mu_0=-2.772  log_lik=-26617.3  noise_std=244.32  log_joint=-26621.9
#   eval  32: ls=0.068  mu_0=-2.632  log_lik=-26616.5  noise_std=244.76  log_joint=-26620.8
#   eval  33: ls=0.110  mu_0=-3.137  log_lik=-26716.8  noise_std=254.39  log_joint=-26722.2
#   eval  34: ls=0.030  mu_0=1.305  log_lik=-26776.8  noise_std=120.58  log_joint=-26779.4
#   eval  35: ls=0.205  mu_0=-2.481  log_lik=-26498.0  noise_std=127.70  log_joint=-26501.3
#      5         35      -26556.01        18.92        13.91        2        346
#   eval  36: ls=0.177  mu_0=-3.096  log_lik=-26506.0  noise_std=132.37  log_joint=-26511.1
#   eval  37: ls=0.031  mu_0=-2.999  log_lik=-27168.1  noise_std=381.42  log_joint=-27174.3
#   eval  38: ls=0.030  mu_0=-3.963  log_lik=-27820.9  noise_std=423.44  log_joint=-27830.5
#   eval  39: ls=0.074  mu_0=2.302  log_lik=-27252.3  noise_std=245.51  log_joint=-27255.7
#   eval  40: ls=0.046  mu_0=-2.540  log_lik=-26658.5  noise_std=236.69  log_joint=-26662.9
#      6         40      -26585.92        20.41        22.34        2        543
#   eval  41: ls=2.500  mu_0=-2.692  log_lik=-26612.9  noise_std=83.85  log_joint=-26617.1
#   eval  42: ls=0.071  mu_0=0.800  log_lik=-26792.2  noise_std=63.11  log_joint=-26793.4
#   eval  43: ls=0.074  mu_0=-2.517  log_lik=-26487.3  noise_std=115.90  log_joint=-26491.3
#   eval  44: ls=2.417  mu_0=-2.147  log_lik=-26700.0  noise_std=63.08  log_joint=-26702.8
#   eval  45: ls=1.918  mu_0=-2.167  log_lik=-26698.2  noise_std=67.35  log_joint=-26700.9
#      7         45      -26592.95        17.36        40.20        2        956
#   eval  46: ls=2.399  mu_0=-2.448  log_lik=-26672.8  noise_std=70.13  log_joint=-26676.3
#   eval  47: ls=2.232  mu_0=-2.288  log_lik=-26683.1  noise_std=68.88  log_joint=-26686.2
#   eval  48: ls=0.040  mu_0=0.084  log_lik=-26688.9  noise_std=68.18  log_joint=-26690.3
#   eval  49: ls=0.062  mu_0=1.641  log_lik=-26814.3  noise_std=81.06  log_joint=-26816.6
#   eval  50: ls=0.032  mu_0=0.883  log_lik=-26822.3  noise_std=63.11  log_joint=-26824.3
#      8         50      -26614.39        18.04        25.41        2        612
#   eval  51: ls=0.117  mu_0=-2.365  log_lik=-26471.5  noise_std=124.61  log_joint=-26474.7
#   eval  52: ls=1.491  mu_0=-2.387  log_lik=-26659.1  noise_std=87.75  log_joint=-26662.2
#   eval  53: ls=0.032  mu_0=-2.745  log_lik=-27083.8  noise_std=364.27  log_joint=-27089.2
#   eval  54: ls=0.039  mu_0=-1.605  log_lik=-26534.1  noise_std=99.38  log_joint=-26536.8
#   eval  55: ls=1.332  mu_0=-2.010  log_lik=-26683.5  noise_std=67.61  log_joint=-26685.7
#      9         55      -26570.05        20.74         8.50        2        222
#   eval  56: ls=0.047  mu_0=0.632  log_lik=-26775.3  noise_std=63.33  log_joint=-26776.8
#   eval  57: ls=1.965  mu_0=-2.479  log_lik=-26681.2  noise_std=70.56  log_joint=-26684.7
#   eval  58: ls=0.031  mu_0=-1.007  log_lik=-26573.1  noise_std=88.06  log_joint=-26575.4
#   eval  59: ls=0.811  mu_0=-3.336  log_lik=-26605.6  noise_std=79.81  log_joint=-26611.2
#   eval  60: ls=0.066  mu_0=-3.718  log_lik=-26770.1  noise_std=293.56  log_joint=-26777.9
#     10         60      -26573.54        28.56      1063.32        2   2.51e+04     trim data
#   eval  61: ls=0.030  mu_0=-3.931  log_lik=-28622.0  noise_std=507.78  log_joint=-28631.5
#   eval  62: ls=0.030  mu_0=-3.701  log_lik=-27580.1  noise_std=428.69  log_joint=-27588.7
#   eval  63: ls=0.036  mu_0=-2.130  log_lik=-26453.1  noise_std=106.88  log_joint=-26456.9
#   eval  64: ls=0.030  mu_0=-2.542  log_lik=-26755.2  noise_std=312.13  log_joint=-26760.2
#   eval  65: ls=0.033  mu_0=-2.642  log_lik=-26737.8  noise_std=301.63  log_joint=-26743.0
#     11         65      -26556.10        29.49       885.44        2   2.09e+04
#   eval  66: ls=0.048  mu_0=-3.996  log_lik=-28096.6  noise_std=465.04  log_joint=-28105.8
#   eval  67: ls=0.030  mu_0=0.424  log_lik=-26746.2  noise_std=66.66  log_joint=-26748.1
#   eval  68: ls=0.030  mu_0=-0.021  log_lik=-26669.3  noise_std=70.39  log_joint=-26671.1
#   eval  69: ls=0.030  mu_0=-2.739  log_lik=-27050.1  noise_std=383.17  log_joint=-27055.6
# /opt/miniconda3/envs/compgenerics/lib/python3.11/site-packages/cma/evolution_strategy.py:3379: RuntimeWarning: invalid value encountered in scalar subtract
#   current_fitness_range < opts['tolfunrel'] * (es.fit.median0 - es.fit.median_min),
# /opt/miniconda3/envs/compgenerics/lib/python3.11/site-packages/cma/evolution_strategy.py:3379: RuntimeWarning: invalid value encountered in scalar multiply
#   current_fitness_range < opts['tolfunrel'] * (es.fit.median0 - es.fit.median_min),
#   eval  70: ls=0.030  mu_0=-2.139  log_lik=-26455.7  noise_std=112.67  log_joint=-26459.7
#     12         70      -26489.95        62.51    413395.10        2   9.74e+06     end warm-up
#   eval  71: ls=0.030  mu_0=-2.579  log_lik=-27063.8  noise_std=370.21  log_joint=-27068.9
#   eval  72: ls=0.030  mu_0=-2.946  log_lik=-27161.1  noise_std=381.17  log_joint=-27167.2
#   eval  73: ls=0.039  mu_0=-2.149  log_lik=-26488.5  noise_std=107.50  log_joint=-26492.3
#   eval  74: ls=0.030  mu_0=-1.571  log_lik=-26511.1  noise_std=96.60  log_joint=-26514.1
#   eval  75: ls=0.037  mu_0=-2.289  log_lik=-26446.1  noise_std=111.04  log_joint=-26450.2
#     13         75      -26500.19        31.41     15770.79        2   3.72e+05
#   eval  76: ls=0.031  mu_0=-2.185  log_lik=-26481.0  noise_std=113.30  log_joint=-26485.1
#   eval  77: ls=0.032  mu_0=-0.709  log_lik=-26585.3  noise_std=82.33  log_joint=-26587.2
#   eval  78: ls=2.434  mu_0=-3.839  log_lik=-26624.3  noise_std=78.17  log_joint=-26632.2
#   eval  79: ls=0.034  mu_0=-3.501  log_lik=-27554.0  noise_std=403.99  log_joint=-27561.8
#   eval  80: ls=1.855  mu_0=-3.146  log_lik=-26671.0  noise_std=78.53  log_joint=-26676.3
#     14         80      -26545.70        29.15         5.63        2        158
#   eval  81: ls=0.030  mu_0=-0.995  log_lik=-26566.8  noise_std=86.90  log_joint=-26569.1
#   eval  82: ls=0.033  mu_0=-0.989  log_lik=-26563.8  noise_std=87.63  log_joint=-26565.9
#   eval  83: ls=0.032  mu_0=0.289  log_lik=-26718.5  noise_std=71.43  log_joint=-26720.2
#   eval  84: ls=0.032  mu_0=-2.611  log_lik=-26644.6  noise_std=306.26  log_joint=-26649.6
#   eval  85: ls=0.046  mu_0=0.156  log_lik=-26694.9  noise_std=70.87  log_joint=-26696.1
#     15         85      -26531.99        41.16         4.19        3        117
#   eval  86: ls=0.030  mu_0=-2.870  log_lik=-27121.8  noise_std=388.64  log_joint=-27127.6
#   eval  87: ls=0.031  mu_0=-0.229  log_lik=-26643.2  noise_std=72.77  log_joint=-26644.9
#   eval  88: ls=0.032  mu_0=-0.003  log_lik=-26691.1  noise_std=72.17  log_joint=-26692.7
#   eval  89: ls=0.640  mu_0=-2.771  log_lik=-26584.3  noise_std=90.53  log_joint=-26588.1
#   eval  90: ls=0.030  mu_0=3.417  log_lik=-27334.7  noise_std=327.61  log_joint=-27342.3
#     16         90      -26541.17        24.49        24.27        3        583
#   eval  91: ls=0.044  mu_0=-2.603  log_lik=-26590.2  noise_std=250.82  log_joint=-26594.9
#   eval  92: ls=1.038  mu_0=-2.990  log_lik=-26632.2  noise_std=71.48  log_joint=-26636.8
#   eval  93: ls=2.499  mu_0=-2.509  log_lik=-26654.4  noise_std=97.87  log_joint=-26658.1
#   eval  94: ls=0.034  mu_0=-3.098  log_lik=-27286.8  noise_std=392.50  log_joint=-27293.2
#   eval  95: ls=0.032  mu_0=-1.862  log_lik=-26495.6  noise_std=112.20  log_joint=-26499.0
#     17         95      -26559.25        17.96        10.08        4        250
#   eval  96: ls=0.030  mu_0=-2.506  log_lik=-26652.7  noise_std=316.13  log_joint=-26657.6
#   eval  97: ls=0.273  mu_0=-2.351  log_lik=-26540.1  noise_std=113.30  log_joint=-26543.0
#   eval  98: ls=0.376  mu_0=-2.592  log_lik=-26560.7  noise_std=103.50  log_joint=-26564.1
#   eval  99: ls=0.922  mu_0=-1.632  log_lik=-26665.7  noise_std=83.73  log_joint=-26667.1
#   eval 100: ls=0.032  mu_0=-3.018  log_lik=-27207.9  noise_std=384.11  log_joint=-27214.2
#     18        100      -26486.31        18.82       477.43        5   1.13e+04
#   eval 101: ls=0.030  mu_0=-3.188  log_lik=-27245.0  noise_std=395.79  log_joint=-27251.8
#   eval 102: ls=0.030  mu_0=-3.026  log_lik=-27284.2  noise_std=378.66  log_joint=-27290.5
#   eval 103: ls=0.035  mu_0=-1.630  log_lik=-26502.0  noise_std=98.82  log_joint=-26504.9
#   eval 104: ls=0.031  mu_0=-2.417  log_lik=-26688.4  noise_std=285.48  log_joint=-26693.0
#   eval 105: ls=0.048  mu_0=-2.372  log_lik=-26626.1  noise_std=236.49  log_joint=-26630.2
#     19        105      -26501.28        37.24       179.83        6   4.26e+03
#   eval 106: ls=0.030  mu_0=-1.756  log_lik=-26493.2  noise_std=100.85  log_joint=-26496.5
#   eval 107: ls=0.031  mu_0=-1.724  log_lik=-26496.3  noise_std=104.58  log_joint=-26499.6
#   eval 108: ls=0.036  mu_0=-1.976  log_lik=-26498.1  noise_std=104.37  log_joint=-26501.6
#   eval 109: ls=0.033  mu_0=-2.009  log_lik=-26484.7  noise_std=107.51  log_joint=-26488.4
#   eval 110: ls=0.062  mu_0=-1.764  log_lik=-26499.4  noise_std=105.77  log_joint=-26502.0
#     20        110      -26509.87        33.86         6.32        6        163
#   eval 111: ls=0.030  mu_0=-1.950  log_lik=-26477.5  noise_std=109.81  log_joint=-26481.1
#   eval 112: ls=0.030  mu_0=-1.653  log_lik=-26492.4  noise_std=99.72  log_joint=-26495.6
#   eval 113: ls=0.030  mu_0=-1.820  log_lik=-26489.7  noise_std=103.67  log_joint=-26493.1
#   eval 114: ls=0.042  mu_0=-1.872  log_lik=-26497.6  noise_std=102.68  log_joint=-26500.7
#   eval 115: ls=0.031  mu_0=-2.085  log_lik=-26444.4  noise_std=109.28  log_joint=-26448.3
#     21        115      -26489.91        26.17         1.73        6       56.1
#   eval 116: ls=0.034  mu_0=-1.773  log_lik=-26469.9  noise_std=103.92  log_joint=-26473.0
#   eval 117: ls=0.050  mu_0=-1.948  log_lik=-26453.4  noise_std=110.00  log_joint=-26456.4
#   eval 118: ls=0.033  mu_0=-1.920  log_lik=-26489.0  noise_std=107.46  log_joint=-26492.5
#   eval 119: ls=0.032  mu_0=-2.053  log_lik=-26477.8  noise_std=104.93  log_joint=-26481.6
#   eval 120: ls=0.032  mu_0=-1.962  log_lik=-26453.5  noise_std=105.01  log_joint=-26457.1
#     22        120      -26486.68        23.67         1.18        6       36.8
#    inf        120      -26486.21        18.85       577.47       50   1.13e+04     finalize
# Inference terminated: reached maximum number of function evaluations options.max_fun_evals.
# Estimated ELBO: -26486.212 +/-18.850.
# Caution: Returned variational solution may have not converged.

# %% [markdown]
# ## Posterior over (length_scale, mu_0)

# %%
phi_samples, _ = vbmc_result.sample(int(1e4))
ls_samples  = np.exp(phi_samples[:, 0]); mu0_samples = phi_samples[:, 1]
print(f"Posterior median: ls={np.median(ls_samples):.3f}  mu_0={np.median(mu0_samples):.3f}")
print(f"95% CI ls:  [{np.percentile(ls_samples,2.5):.3f}, {np.percentile(ls_samples,97.5):.3f}]")
print(f"95% CI mu_0: [{np.percentile(mu0_samples,2.5):.3f}, {np.percentile(mu0_samples,97.5):.3f}]")
print(f"convergence: {vbmc_stats['convergence_status']}  (evals {vbmc_stats['func_count']}, ELBO {vbmc_stats['elbo']:.1f})")

fig, axes = plt.subplots(1, 3, figsize=(14, 4))
axes[0].hist(ls_samples, bins=50, density=True, color='steelblue', alpha=0.7)
axes[0].axvline(np.median(ls_samples), color='tomato', lw=2, label=f'median={np.median(ls_samples):.2f}')
axes[0].set_xlabel('length_scale'); axes[0].set_title('Posterior: length_scale'); axes[0].legend()
axes[1].hist(mu0_samples, bins=50, density=True, color='seagreen', alpha=0.7)
axes[1].axvline(np.median(mu0_samples), color='tomato', lw=2, label=f'median={np.median(mu0_samples):.2f}')
axes[1].set_xlabel('mu_0'); axes[1].set_title('Posterior: mu_0'); axes[1].legend()
axes[2].scatter(ls_samples[::10], mu0_samples[::10], alpha=0.1, s=2, color='purple')
axes[2].set_xlabel('length_scale'); axes[2].set_ylabel('mu_0'); axes[2].set_title('Joint posterior')
plt.tight_layout(); plt.show()
# Out:
# Posterior median: ls=0.030  mu_0=-3.455
# 95% CI ls:  [0.030, 0.030]
# 95% CI mu_0: [-3.612, -3.243]
# convergence: no  (evals 120, ELBO -26486.2)

# %% [markdown]
# ## Forward pass: predicted prevalence per condition vs empirical
#
# `E[p'|u] = pz1*mean_kl + (1-pz1)*mean_nkl` with shapes shared across conditions and `pz1`
# condition-specific. The condition x trait heatmaps show whether training a region raises its
# matched-trait test features (the diagonal), in both prediction and data.

# %%
ls_m, mu0_m = float(ls_samples.mean()), float(mu0_samples.mean())
params_best = {**FIXED_PARAMS, 'length_scale': ls_m, 'mu_0': mu0_m}
print(f"Forward pass at ls={ls_m:.3f}, mu_0={mu0_m:.3f}")

# per-condition coherence at posterior mean
pz1_bar = {c: condition_pz1_draws(x_train_cond[c], u_train_cond[c], params_best).mean(0) for c in CONDITIONS}
# shared shapes at posterior mean
pz1_weights = jnp.concatenate([jnp.tile(jnp.array(pz1_bar[c]), (N_cond[c], 1)) for c in CONDITIONS], axis=0)
beta_params = fit_beta_mixtures_all_features(responses_all, pz1_weights)
a_kl, b_kl, a_nkl, b_nkl = [np.array(beta_params[:, i]) for i in range(4)]
mean_kl, mean_nkl = a_kl/(a_kl+b_kl), a_nkl/(a_nkl+b_nkl)

pred_cond = {c: pz1_bar[c]*mean_kl + (1-pz1_bar[c])*mean_nkl for c in CONDITIONS}  # E[p'|u] per cond
emp_cond  = {c: np.array(responses_cond[c]).mean(0) for c in CONDITIONS}
traits = np.array(test_trait); tcolor = {'diet':'tab:green','personality':'tab:purple','physical':'tab:orange'}

# (1) predicted vs empirical per condition; matched-trait points outlined
fig, axes = plt.subplots(1, 4, figsize=(18, 4.5), sharex=True, sharey=True)
for ax, c in zip(axes, CONDITIONS):
    for tr in tcolor:
        m = traits == tr
        ax.scatter(emp_cond[c][m], pred_cond[c][m], s=70, color=tcolor[tr],
                   edgecolor=('k' if tr == c else 'none'), linewidth=1.5, label=tr)
    ax.plot([0,1],[0,1],'--',color='gray',alpha=0.5); ax.set_xlim(0,1); ax.set_ylim(0,1)
    ax.set_title(f"{c}  (matched outlined)"); ax.set_xlabel('empirical mean')
axes[0].set_ylabel("predicted E[p'|u]"); axes[0].legend(fontsize=8, title='test trait')
r_all = np.corrcoef(np.concatenate([emp_cond[c] for c in CONDITIONS]),
                    np.concatenate([pred_cond[c] for c in CONDITIONS]))[0,1]
fig.suptitle(f'Predicted vs empirical prevalence by condition  (pooled r={r_all:.3f})')
plt.tight_layout(); plt.show()

# (2) condition x test-trait elevation: predicted vs empirical (diagonal = matched)
def by_trait(d):
    return np.array([[d[c][traits==tr].mean() for tr in ['diet','personality','physical']] for c in CONDITIONS])
pred_mat, emp_mat = by_trait(pred_cond), by_trait(emp_cond)
fig, axes = plt.subplots(1, 2, figsize=(11, 4.5))
for ax, mat, ttl in [(axes[0], pred_mat, "PREDICTED E[p'|u]"), (axes[1], emp_mat, 'EMPIRICAL mean')]:
    im = ax.imshow(mat, aspect='auto', cmap='viridis')
    ax.set_xticks(range(3)); ax.set_xticklabels(['diet','personality','physical'])
    ax.set_yticks(range(4)); ax.set_yticklabels(CONDITIONS)
    ax.set_xlabel('test-feature trait'); ax.set_ylabel('condition (trained)'); ax.set_title(ttl)
    for i in range(4):
        for j in range(3):
            ax.text(j, i, f"{mat[i,j]:.2f}", ha='center', va='center', fontsize=9,
                    color='white' if mat[i,j] < mat.mean() else 'black')
    plt.colorbar(im, ax=ax)
fig.suptitle('Does training a region raise matched-trait test features? (rows trained, cols tested)')
plt.tight_layout(); plt.show()
# Out:
# Forward pass at ls=0.030, mu_0=-3.448
